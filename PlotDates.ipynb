# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import calendar

# %%
# Load and view dataframe
fireData = pd.read_csv("updatedFire.csv", index_col = "_id", low_memory = False)
fireData
# Out:
#         OBJECTID         * Damage  * Street Number  * Street Name  \
# _id
# 1              1        No Damage           8376.0   Quail Canyon
# 2              2  Affected (1-9%)           8402.0   Quail Canyon
# 3              3        No Damage           8430.0  Quail Canyon
# 4              4        No Damage           3838.0    Putah Creek
# 5              5        No Damage           3830.0    Putah Creek
# ...          ...              ...              ...            ...
# 100226    101217        No Damage          24198.0           Case
# 100227    101218        No Damage          24198.0           Case
# 100228    101219        No Damage          24198.0           Case
# 100229    101220        No Damage          24008.0         Malibu
# 100230    101221        No Damage          24016.0         Malibu
#
#        * Street Type (e.g. road, drive, lane, etc.)   * City  Zip Code  \
# _id
# 1                                              Road  Winters       NaN
# 2                                              Road  Winters       NaN
# 3                                              Road  Winters       NaN
# 4                                              Road  Winters       NaN
# 5                                              Road  Winters       NaN
# ...                                             ...      ...       ...
# 100226                                        Court   Malibu   90265.0
# 100227                                        Court   Malibu   90265.0
# 100228                                        Court   Malibu   90265.0
# 100229                                         Road   Malibu   90265.0
# 100230                                         Road   Malibu   90265.0
#
#        * CAL FIRE Unit       County * Incident Name  ...  \
# _id                                                  ...
# 1                  LNU       Solano           Quail  ...
# 2                  LNU       Solano           Quail  ...
# 3                  LNU       Solano           Quail  ...
# 4                  LNU       Solano           Quail  ...
# 5                  LNU       Solano           Quail  ...
# ...                ...          ...             ...  ...
# 100226             LAC  Los Angeles        Franklin  ...
# 100227             LAC  Los Angeles        Franklin  ...
# 100228             LAC  Los Angeles        Franklin  ...
# 100229             LAC  Los Angeles        Franklin  ...
# 100230             LAC  Los Angeles        Franklin  ...
#
#        Distance - Residence to Utility/Misc Structure &gt; 120 SQFT  \
# _id
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 100226                                                NaN
# 100227                                                NaN
# 100228                                                NaN
# 100229                                                NaN
# 100230                                                NaN
#
#        Fire Name (Secondary)                              GLOBALID   Latitude  \
# _id
# 1                      Quail  e1919a06-b4c6-476d-99e5-f0b45b070de8  38.474960
# 2                      Quail  b090eeb6-5b18-421e-9723-af7c9144587c  38.477442
# 3                      Quail  268da70b-753f-46aa-8fb1-327099337395  38.479358
# 4                      Quail  64d4a278-5ee9-414a-8bf4-247c5b5c60f9  38.487313
# 5                      Quail  1b44b214-01fd-4f06-b764-eb42a1ec93d7  38.485636
# ...                      ...                                   ...        ...
# 100226                   NaN  1b537de2-8b97-43ee-9d5c-c5a426f604f1  34.033408
# 100227                   NaN  56e3cc8b-4bf0-4beb-bd26-b54422cc31ee  34.033278
# 100228                   NaN  f85e9f02-a67f-4a7d-9fa1-0b8bf419d51a  34.033618
# 100229                   NaN  51b2df1f-852e-4f36-b250-b383c93e4042  34.032085
# 100230                   NaN  f881c0c8-37bc-485d-b730-03980fae9e30  34.031957
#
#          Longitude             x             y  Day  Month  Year
# _id
# 1      -122.044465 -1.358593e+07  4.646741e+06    6      6  2020
# 2      -122.043252 -1.358579e+07  4.647094e+06    6      6  2020
# 3      -122.044585 -1.358594e+07  4.647366e+06    6      6  2020
# 4      -122.015115 -1.358266e+07  4.648497e+06    6      6  2020
# 5      -122.016122 -1.358277e+07  4.648259e+06    6      6  2020
# ...            ...           ...           ...  ...    ...   ...
# 100226 -118.700625 -1.321369e+07  4.033289e+06    9     12  2024
# 100227 -118.700902 -1.321372e+07  4.033271e+06    9     12  2024
# 100228 -118.701102 -1.321375e+07  4.033317e+06    9     12  2024
# 100229 -118.698270 -1.321343e+07  4.033111e+06    9     12  2024
# 100230 -118.698497 -1.321346e+07  4.033094e+06    9     12  2024
#
# [100230 rows x 39 columns]

# %%
# Check what years are recorded in the data
unique_years = fireData['Year'].unique()
print(unique_years)
# Out:
# [2020 2018 2017 2014 2015 2016 2013 2019 2021 2022 2023 2024]

# %%
# Count number of incidents per (year, month)
incidents_per_year_month = fireData.groupby(['Year', 'Month']).size().unstack(fill_value=0)

# Define positions for grouped bars
years = incidents_per_year_month.index
months = np.arange(1, 13)  # Months 1-12
width = 0.07  # Width of each bar
x = np.arange(len(years))  # X positions for groups

# Create a colormap for months
cmap = plt.colormaps.get_cmap('tab20')
colors = [cmap(i) for i in range(12)]  # Extract 12 distinct colors

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

for i, month in enumerate(months):
    if month in incidents_per_year_month.columns:
        ax.bar(x + (i - 5.5) * width,  # Offset bars for grouping
               incidents_per_year_month[month], 
               width=width, 
               label=calendar.month_name[month],
               color=colors[month-1])

# X-axis labels and formatting
ax.set_xticks(x)
ax.set_xticklabels(years)
ax.set_xlabel("Years")
ax.set_ylabel("Number of Incidents")
ax.set_title("Number of Incidents per Month and Year")
ax.legend(title="Months", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()
